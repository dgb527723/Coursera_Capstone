# %% [markdown]
#     --Hello this is my Notebook for the Capstone

# %% [markdown]
# https://github.com/dgb527723/Coursera_Capstone/blob/master/Coursera%20Capstone%20Project.ipynb

# %%
import numpy as np

# %%
import pandas as pd

# %%
print('Hello Coursera Project Course')
# Out:
# Hello Coursera Project Course
